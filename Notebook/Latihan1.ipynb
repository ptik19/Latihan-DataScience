# %% [markdown]
# # Overview Latihan 1 - PTIK Data Science
# Buatlah program untuk menghitung banyaknya transaksi yang terjadi di supermarket X yang berada di negara Kanada selama bulan November 2016. Gunakan data dari file Excel transaksi belanja (Sample - Superstore.xls)

# %% [markdown]
# # Mempersiapkan Data

# %%
import pandas as pd
import numpy as np

# %%
os.listdir('../Data')
# Out:
# ['AppleStore.csv',
#  'Sample%20-%20Superstore.xls',
#  'denver-crimes.zip',
#  'top-250-football-transfers-from-2000-to-2018.zip',
#  'weight-height.csv',
#  'world.sql.zip']

# %%
# Loading data excel ke dalam notebook dengan pandas
df = pd.read_excel('../Data/Sample%20-%20Superstore.xls')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0       1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1       2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 2       3  CA-2016-138688 2016-06-12  ...        2     0.00    6.8714
# 3       4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 4       5  US-2015-108966 2015-10-11  ...        2     0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.head(1).T
# Out:
#                                                0
# Row ID                                         1
# Order ID                          CA-2016-152156
# Order Date                   2016-11-08 00:00:00
# Ship Date                    2016-11-11 00:00:00
# Ship Mode                           Second Class
# Customer ID                             CG-12520
# Customer Name                        Claire Gute
# Segment                                 Consumer
# Country                            United States
# City                                   Henderson
# State                                   Kentucky
# Postal Code                                42420
# Region                                     South
# Product ID                       FUR-BO-10001798
# Category                               Furniture
# Sub-Category                           Bookcases
# Product Name   Bush Somerset Collection Bookcase
# Sales                                     261.96
# ...

# %% [markdown]
# # Seleksi Data

# %%
# Menampilkan 10 random sample dari dataframe
df['Order ID'].sample(n=10)
# Out:
# 7745    CA-2016-133613
# 3721    CA-2016-151155
# 4009    CA-2017-144463
# 5113    CA-2016-147970
# 2094    US-2015-164357
# 3758    CA-2015-167745
# 7573    CA-2014-100916
# 7139    CA-2015-163965
# 3588    CA-2017-158729
# 983     CA-2014-163419
# Name: Order ID, dtype: object

# %%
order = df['Order ID'].apply(lambda x : x[:2])

# %%
order.head()
# Out:
# 0    CA
# 1    CA
# 2    CA
# 3    US
# 4    US
# Name: Order ID, dtype: object

# %%
order.value_counts()
# Out:
# CA    8308
# US    1686
# Name: Order ID, dtype: int64

# %% [markdown]
# ## Seleksi Order di Canada

# %%
# Seleksi order CA untuk Canada
df = df[order == 'CA']

# %%
# Reset Index dataframe
df.reset_index(drop=True,inplace=True)

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  ... Quantity Discount   Profit
# 8303    9990  CA-2014-110422 2014-01-21  ...        3      0.2   4.1028
# 8304    9991  CA-2017-121258 2017-02-26  ...        2      0.0  15.6332
# 8305    9992  CA-2017-121258 2017-02-26  ...        2      0.2  19.3932
# 8306    9993  CA-2017-121258 2017-02-26  ...        4      0.0  13.3200
# 8307    9994  CA-2017-119914 2017-05-04  ...        2      0.0  72.9480
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Seleksi Order November 2016

# %%
import datetime

# %%
# Filter tanggal 1-11-2016 sd 30-11-2016 aka November 2016
df = df[df['Order Date'] >= pd.Timestamp(2016,11,1)]
df = df[df['Order Date'] <= pd.Timestamp(2016,11,30)]

# %%
# Reset dataframe index
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Hasil Akhir
# Terdapat 313 order dari Canada pada bulan November tahun 2016

# %%
# Hasil akhir dataframe, order di Canada pada bulan November 2016
df
# Out:
#      Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0         1  CA-2016-152156 2016-11-08  ...        2      0.0   41.9136
# 1         2  CA-2016-152156 2016-11-08  ...        3      0.0  219.5820
# 2       112  CA-2016-128867 2016-11-03  ...        2      0.0   22.7880
# 3       113  CA-2016-128867 2016-11-03  ...        6      0.0   13.3476
# 4       159  CA-2016-114104 2016-11-20  ...        2      0.0    6.8714
# ..      ...             ...        ...  ...      ...      ...       ...
# 308    9772  CA-2016-123533 2016-11-24  ...        2      0.2    4.2384
# 309    9812  CA-2016-117583 2016-11-27  ...        4      0.0   12.4416
# 310    9813  CA-2016-117583 2016-11-27  ...        3      0.0    9.7020
# 311    9814  CA-2016-117583 2016-11-27  ...        5      0.0  100.4255
# 312    9815  CA-2016-117583 2016-11-27  ...        5      0.0   38.3760
#
# [313 rows x 21 columns]
